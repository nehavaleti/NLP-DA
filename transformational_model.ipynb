# %%
pip install torch transformers datasets
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu118)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import load_dataset, load_metric
import torch

# %%
import pandas as pd
from datasets import Dataset

# Load the dataset from the CSV file
csv_file_path = '/train.csv'  # Replace with your CSV file path
df = pd.read_csv(csv_file_path, header=None, names=['text'])

# Convert the DataFrame into a Hugging Face dataset
dataset = Dataset.from_pandas(df)

# %%
dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 4937
# })

# %%
# Choose the appropriate model checkpoint
model_checkpoint = "t5-base"  # Or any other appropriate model

# Initialize the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# Tokenize function to encode the texts
def tokenize_function(examples):
    # Tokenize the text into input IDs and attention masks
    return tokenizer(examples["text"], padding="max_length", truncation=True)

# Apply the tokenize function to all sentences in the dataset
tokenized_dataset = dataset.map(tokenize_function, batched=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5_fast.py:160: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# Map:   0%|          | 0/4937 [00:00<?, ? examples/s]

# %%
from transformers import pipeline

# Use a pre-trained model for translation from English to Hindi
translator = pipeline('translation_en_to_hi', model='Helsinki-NLP/opus-mt-en-hi')
# Out:
# source.spm:   0%|          | 0.00/812k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
# Function to translate a batch of texts
def translate_batch(texts):
    translations = translator(texts, max_length=512)
    return [translation['translation_text'] for translation in translations]

# Batch size (you may adjust this depending on your hardware)
batch_size = 10

# Container for the translated texts
translated_texts = []

# Translate in batches
for i in range(0, len(tokenized_dataset), batch_size):
    batch_texts = tokenized_dataset[i:i+batch_size]['text']
    batch_translations = translate_batch(batch_texts)
    translated_texts.extend(batch_translations)

    # Optional: Print progress
    print(f"Translated {i + len(batch_translations)}/{len(tokenized_dataset)} sentences")

# Add the translations to the original dataset
tokenized_dataset = tokenized_dataset.add_column('hindi_translation', translated_texts)
# Out:
# Translated 10/4937 sentences
# Translated 20/4937 sentences
# Translated 30/4937 sentences
# Translated 40/4937 sentences
# Translated 50/4937 sentences
# Translated 60/4937 sentences
# Translated 70/4937 sentences
# Translated 80/4937 sentences
# Translated 90/4937 sentences
# Translated 100/4937 sentences
# Translated 110/4937 sentences
# Translated 120/4937 sentences
# Translated 130/4937 sentences
# Translated 140/4937 sentences
# Translated 150/4937 sentences
# Translated 160/4937 sentences
# Translated 170/4937 sentences
# Translated 180/4937 sentences
# Translated 190/4937 sentences
# Translated 200/4937 sentences
# Translated 210/4937 sentences
# Translated 220/4937 sentences
# Translated 230/4937 sentences
# Translated 240/4937 sentences
# Translated 250/4937 sentences
# Translated 260/4937 sentences
# Translated 270/4937 sentences
# Translated 280/4937 sentences
# Translated 290/4937 sentences
# Translated 300/4937 sentences
# Translated 310/4937 sentences
# Translated 320/4937 sentences
# Translated 330/4937 sentences
# Translated 340/4937 sentences
# Translated 350/4937 sentences
# Translated 360/4937 sentences
# Translated 370/4937 sentences
# Translated 380/4937 sentences
# Translated 390/4937 sentences
# Translated 400/4937 sentences
# Translated 410/4937 sentences
# Translated 420/4937 sentences
# Translated 430/4937 sentences
# Translated 440/4937 sentences
# Translated 450/4937 sentences
# Translated 460/4937 sentences
# Translated 470/4937 sentences
# Translated 480/4937 sentences
# Translated 490/4937 sentences
# Translated 500/4937 sentences
# Translated 510/4937 sentences
# Translated 520/4937 sentences
# Translated 530/4937 sentences
# Translated 540/4937 sentences
# Translated 550/4937 sentences
# Translated 560/4937 sentences
# Translated 570/4937 sentences
# Translated 580/4937 sentences
# Translated 590/4937 sentences
# Translated 600/4937 sentences
# Translated 610/4937 sentences
# Translated 620/4937 sentences
# Translated 630/4937 sentences
# Translated 640/4937 sentences
# Translated 650/4937 sentences
# Translated 660/4937 sentences
# Translated 670/4937 sentences
# Translated 680/4937 sentences
# Translated 690/4937 sentences
# Translated 700/4937 sentences
# Translated 710/4937 sentences
# Translated 720/4937 sentences
# Translated 730/4937 sentences
# Translated 740/4937 sentences
# Translated 750/4937 sentences
# Translated 760/4937 sentences
# Translated 770/4937 sentences
# Translated 780/4937 sentences
# Translated 790/4937 sentences
# Translated 800/4937 sentences
# Translated 810/4937 sentences
# Translated 820/4937 sentences
# Translated 830/4937 sentences
# Translated 840/4937 sentences
# Translated 850/4937 sentences
# Translated 860/4937 sentences
# Translated 870/4937 sentences
# Translated 880/4937 sentences
# Translated 890/4937 sentences
# Translated 900/4937 sentences
# Translated 910/4937 sentences
# Translated 920/4937 sentences
# Translated 930/4937 sentences
# Translated 940/4937 sentences
# Translated 950/4937 sentences
# Translated 960/4937 sentences
# Translated 970/4937 sentences
# Translated 980/4937 sentences
# Translated 990/4937 sentences
# Translated 1000/4937 sentences
# Translated 1010/4937 sentences
# Translated 1020/4937 sentences
# Translated 1030/4937 sentences
# Translated 1040/4937 sentences
# Translated 1050/4937 sentences
# Translated 1060/4937 sentences
# Translated 1070/4937 sentences
# Translated 1080/4937 sentences
# Translated 1090/4937 sentences
# Translated 1100/4937 sentences
# Translated 1110/4937 sentences
# Translated 1120/4937 sentences
# Translated 1130/4937 sentences
# Translated 1140/4937 sentences
# Translated 1150/4937 sentences
# Translated 1160/4937 sentences
# Translated 1170/4937 sentences
# Translated 1180/4937 sentences
# Translated 1190/4937 sentences
# Translated 1200/4937 sentences
# Translated 1210/4937 sentences
# Translated 1220/4937 sentences
# Translated 1230/4937 sentences
# Translated 1240/4937 sentences
# Translated 1250/4937 sentences
# Translated 1260/4937 sentences
# Translated 1270/4937 sentences
# Translated 1280/4937 sentences
# Translated 1290/4937 sentences
# Translated 1300/4937 sentences
# Translated 1310/4937 sentences
# Translated 1320/4937 sentences
# Translated 1330/4937 sentences
# Translated 1340/4937 sentences
# Translated 1350/4937 sentences
# Translated 1360/4937 sentences
# Translated 1370/4937 sentences
# Translated 1380/4937 sentences
# Translated 1390/4937 sentences
# Translated 1400/4937 sentences
# Translated 1410/4937 sentences
# Translated 1420/4937 sentences
# Translated 1430/4937 sentences
# Translated 1440/4937 sentences
# Translated 1450/4937 sentences
# Translated 1460/4937 sentences
# Translated 1470/4937 sentences
# Translated 1480/4937 sentences
# Translated 1490/4937 sentences
# Translated 1500/4937 sentences
# Translated 1510/4937 sentences
# Translated 1520/4937 sentences
# Translated 1530/4937 sentences
# Translated 1540/4937 sentences
# Translated 1550/4937 sentences
# Translated 1560/4937 sentences
# Translated 1570/4937 sentences
# Translated 1580/4937 sentences
# Translated 1590/4937 sentences
# Translated 1600/4937 sentences
# Translated 1610/4937 sentences
# Translated 1620/4937 sentences
# Translated 1630/4937 sentences
# Translated 1640/4937 sentences
# Translated 1650/4937 sentences
# Translated 1660/4937 sentences
# Translated 1670/4937 sentences
# Translated 1680/4937 sentences
# Translated 1690/4937 sentences
# Translated 1700/4937 sentences
# Translated 1710/4937 sentences
# Translated 1720/4937 sentences
# Translated 1730/4937 sentences
# Translated 1740/4937 sentences
# Translated 1750/4937 sentences
# Translated 1760/4937 sentences
# Translated 1770/4937 sentences
# Translated 1780/4937 sentences
# Translated 1790/4937 sentences
# Translated 1800/4937 sentences
# Translated 1810/4937 sentences
# Translated 1820/4937 sentences
# Translated 1830/4937 sentences
# Translated 1840/4937 sentences
# Translated 1850/4937 sentences
# Translated 1860/4937 sentences
# Translated 1870/4937 sentences
# Translated 1880/4937 sentences
# Translated 1890/4937 sentences
# Translated 1900/4937 sentences
# Translated 1910/4937 sentences
# Translated 1920/4937 sentences
# Translated 1930/4937 sentences
# Translated 1940/4937 sentences
# Translated 1950/4937 sentences
# Translated 1960/4937 sentences
# Translated 1970/4937 sentences
# Translated 1980/4937 sentences
# Translated 1990/4937 sentences
# Translated 2000/4937 sentences
# Translated 2010/4937 sentences
# Translated 2020/4937 sentences
# Translated 2030/4937 sentences
# Translated 2040/4937 sentences
# Translated 2050/4937 sentences
# Translated 2060/4937 sentences
# Translated 2070/4937 sentences
# Translated 2080/4937 sentences
# Translated 2090/4937 sentences
# Translated 2100/4937 sentences
# Translated 2110/4937 sentences
# Translated 2120/4937 sentences
# Translated 2130/4937 sentences
# Translated 2140/4937 sentences
# Translated 2150/4937 sentences
# Translated 2160/4937 sentences
# Translated 2170/4937 sentences
# Translated 2180/4937 sentences
# Translated 2190/4937 sentences
# Translated 2200/4937 sentences
# Translated 2210/4937 sentences
# Translated 2220/4937 sentences
# Translated 2230/4937 sentences
# Translated 2240/4937 sentences
# Translated 2250/4937 sentences
# Translated 2260/4937 sentences
# Translated 2270/4937 sentences
# Translated 2280/4937 sentences
# Translated 2290/4937 sentences
# Translated 2300/4937 sentences
# Translated 2310/4937 sentences
# Translated 2320/4937 sentences
# Translated 2330/4937 sentences
# Translated 2340/4937 sentences
# Translated 2350/4937 sentences
# Translated 2360/4937 sentences
# Translated 2370/4937 sentences
# Translated 2380/4937 sentences
# Translated 2390/4937 sentences
# Translated 2400/4937 sentences
# Translated 2410/4937 sentences
# Translated 2420/4937 sentences
# Translated 2430/4937 sentences
# Translated 2440/4937 sentences
# Translated 2450/4937 sentences
# Translated 2460/4937 sentences
# Translated 2470/4937 sentences
# Translated 2480/4937 sentences
# Translated 2490/4937 sentences
# Translated 2500/4937 sentences
# Translated 2510/4937 sentences
# Translated 2520/4937 sentences
# Translated 2530/4937 sentences
# Translated 2540/4937 sentences
# Translated 2550/4937 sentences
# Translated 2560/4937 sentences
# Translated 2570/4937 sentences
# Translated 2580/4937 sentences
# Translated 2590/4937 sentences
# Translated 2600/4937 sentences
# Translated 2610/4937 sentences
# Translated 2620/4937 sentences
# Translated 2630/4937 sentences
# Translated 2640/4937 sentences
# Translated 2650/4937 sentences
# Translated 2660/4937 sentences
# Translated 2670/4937 sentences
# Translated 2680/4937 sentences
# Translated 2690/4937 sentences
# Translated 2700/4937 sentences
# Translated 2710/4937 sentences
# Translated 2720/4937 sentences
# Translated 2730/4937 sentences
# Translated 2740/4937 sentences
# Translated 2750/4937 sentences
# Translated 2760/4937 sentences
# Translated 2770/4937 sentences
# Translated 2780/4937 sentences
# Translated 2790/4937 sentences
# Translated 2800/4937 sentences
# Translated 2810/4937 sentences
# Translated 2820/4937 sentences
# Translated 2830/4937 sentences
# Translated 2840/4937 sentences
# Translated 2850/4937 sentences
# Translated 2860/4937 sentences
# Translated 2870/4937 sentences
# Translated 2880/4937 sentences
# Translated 2890/4937 sentences
# Translated 2900/4937 sentences
# Translated 2910/4937 sentences
# Translated 2920/4937 sentences
# Translated 2930/4937 sentences
# Translated 2940/4937 sentences
# Translated 2950/4937 sentences
# Translated 2960/4937 sentences
# Translated 2970/4937 sentences
# Translated 2980/4937 sentences
# Translated 2990/4937 sentences
# Translated 3000/4937 sentences
# Translated 3010/4937 sentences
# Translated 3020/4937 sentences
# Translated 3030/4937 sentences
# Translated 3040/4937 sentences
# Translated 3050/4937 sentences
# Translated 3060/4937 sentences
# Translated 3070/4937 sentences
# Translated 3080/4937 sentences
# Translated 3090/4937 sentences
# Translated 3100/4937 sentences
# Translated 3110/4937 sentences
# Translated 3120/4937 sentences
# Translated 3130/4937 sentences
# Translated 3140/4937 sentences
# Translated 3150/4937 sentences
# Translated 3160/4937 sentences
# Translated 3170/4937 sentences
# Translated 3180/4937 sentences
# Translated 3190/4937 sentences
# Translated 3200/4937 sentences
# Translated 3210/4937 sentences
# Translated 3220/4937 sentences
# Translated 3230/4937 sentences
# Translated 3240/4937 sentences
# Translated 3250/4937 sentences
# Translated 3260/4937 sentences
# Translated 3270/4937 sentences
# Translated 3280/4937 sentences
# Translated 3290/4937 sentences
# Translated 3300/4937 sentences
# Translated 3310/4937 sentences
# Translated 3320/4937 sentences
# Translated 3330/4937 sentences
# Translated 3340/4937 sentences
# Translated 3350/4937 sentences
# Translated 3360/4937 sentences
# Translated 3370/4937 sentences
# Translated 3380/4937 sentences
# Translated 3390/4937 sentences
# Translated 3400/4937 sentences
# Translated 3410/4937 sentences
# Translated 3420/4937 sentences
# Translated 3430/4937 sentences
# Translated 3440/4937 sentences
# Translated 3450/4937 sentences
# Translated 3460/4937 sentences
# Translated 3470/4937 sentences
# Translated 3480/4937 sentences
# Translated 3490/4937 sentences
# Translated 3500/4937 sentences
# Translated 3510/4937 sentences
# Translated 3520/4937 sentences
# Translated 3530/4937 sentences
# Translated 3540/4937 sentences
# Translated 3550/4937 sentences
# Translated 3560/4937 sentences
# Translated 3570/4937 sentences
# Translated 3580/4937 sentences
# Translated 3590/4937 sentences
# Translated 3600/4937 sentences
# Translated 3610/4937 sentences
# Translated 3620/4937 sentences
# Translated 3630/4937 sentences
# Translated 3640/4937 sentences
# Translated 3650/4937 sentences
# Translated 3660/4937 sentences
# Translated 3670/4937 sentences
# Translated 3680/4937 sentences
# Translated 3690/4937 sentences
# Translated 3700/4937 sentences
# Translated 3710/4937 sentences
# Translated 3720/4937 sentences
# Translated 3730/4937 sentences
# Translated 3740/4937 sentences
# Translated 3750/4937 sentences
# Translated 3760/4937 sentences
# Translated 3770/4937 sentences
# Translated 3780/4937 sentences
# Translated 3790/4937 sentences
# Translated 3800/4937 sentences
# Translated 3810/4937 sentences
# Translated 3820/4937 sentences
# Translated 3830/4937 sentences
# Translated 3840/4937 sentences
# Translated 3850/4937 sentences
# Translated 3860/4937 sentences
# Translated 3870/4937 sentences
# Translated 3880/4937 sentences
# Translated 3890/4937 sentences
# Translated 3900/4937 sentences
# Translated 3910/4937 sentences
# Translated 3920/4937 sentences
# Translated 3930/4937 sentences
# Translated 3940/4937 sentences
# Translated 3950/4937 sentences
# Translated 3960/4937 sentences
# Translated 3970/4937 sentences
# Translated 3980/4937 sentences
# Translated 3990/4937 sentences
# Translated 4000/4937 sentences
# Translated 4010/4937 sentences
# Translated 4020/4937 sentences
# Translated 4030/4937 sentences
# Translated 4040/4937 sentences
# Translated 4050/4937 sentences
# Translated 4060/4937 sentences

# %%
# Convert the dataset to a pandas DataFrame
translated_df = tokenized_dataset.to_pandas()

# Save the DataFrame to a CSV file
translated_df.to_csv('translated_dataset.csv', index=False)
